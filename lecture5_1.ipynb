# %%
def func(value,values):
    var=1
    values[0]=44
t=3
v=[1,2,3]
func(t,v)
print(t,v[0])
# Out:
# 3 44

# %%
def f(i, values=[]):
    values.append(i)
    print(values)
f(1)
f(2)
f(3)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
#queue
# Queue using list:
# 1. easy to implement
# 2. speed problem when it grows

# Queue using linked list
# 1.fast performance
# 2.implementation is not easy

import sys
class Queue:
    def __init__(self,size):
        self.myQueue=[]
        self.queueSize = size
        
    def isFull(self):
        if len(self.myQueue) == size:
            return True
        else:
            return False

    def isEmpty(self):
        if self.myQueue ==[]:
            return True
        else:
            return False

    def enQueue(self,value):
        if self.isFull():
            print("Queue is full")
        else:
            self.myQueue.append(value)

    def dispay(self):
        print(self.myQueue)

    def delOption(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            self.myQueue.pop(0)

    def peek(self):
        if self.isEmpty():
            print("Queue is Empty")
        else:
            print(self.myQueue[0])

    def delQueue(self):
        self.myQueue = none
            
        

size=int(input("Enter the size of Queue:"))
obj = Queue(size) #O(1)
print("Queue has created:" )

while True:
    print("1. Enqueue Operation")  #O(n)
    print("2. Display Queue:")   
    print("3. Delete Operation")   #
    print("4. Peek Operation:")
    print("5. Delete Queue")
    print("6. Exit")
    choice= int(input("Enter value to enqueue your choice: "))
    if choice == 1:
        value=int(input("Enter element to add in Queue"))
        obj.enQueue(value):
    elif choice == 2:
        obj.display()
    elif choice == 3:
        obj.delOption()
    elif choice == 4:
        obj.peek()
    elif choice == 5:
        obj.delQueue()
    elif choice == 6:
        break

# %%
fruit = {}
def addone(index):
    if index in fruit:
        fruit[index] = +1
    else:
        fruit[index] = 1
addone("Apple")
addone("Banana")
addone("apple")
print(len(fruit))
# Out:
# 3

# %%
std={}
def addstd()
addstdinput("")
