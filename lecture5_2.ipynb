# %%
s="learning python is very easy"
n=len(s)
i=0
print("forward direction")
while i<n:
    print(s[i],end= '')
    i+=1
print("backward direction")
i=1
while i>=-n:
    print(s[i],end='')
    i=i-1
# Out:
# forward direction
# learning python is very easybackward direction
# elysae yrev si nohtyp gninrael

# %%
v=['a','e','i','o','u']
w=input("enter the word where will search the vowels:")
found=[]
for i in w:
    if i in v:
        if i not in found:
            found.append(i)
print('found vowels:',found)
print('unique vowels:',len(found),'from the given word=',w)
# Out:
# enter the word where will search the vowels: people may be absent today
# found vowels: ['e', 'o', 'a']
# unique vowels: 3 from the given word= people may be absent today

# %%
# x,y,z=map(int,input().split())
# mylist=[]
# for i in range(x):
#     a=int(input())
#     mylist.append(a)
# for j in mylist:
#     if j>=y and j<=z:
#         print(j,end=' ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x,y,z=map(int,input().split())
#       2 mylist=[]
#       3 for i in range(x):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import datetime
date = datetime.datetime.now()
print("its now:{:%d/%m/%Y %H/%M/%S}".format(date))
# Out:
# its now:16/05/2026 14/53/18

# %%
x=['A','B','C']
y=['A','B','C']
z=[1,2,3,4]
print(x==y)
print(x==z)
print(x!=z)
# Out:
# True
# False
# True

# %%
s=[1,4,9,16,25,36,49,64,81,100]
val=[2**i for i in range(1,6)]
print(val)
val2=[i for i in s if i%2==0]
print(val2)
# Out:
# [2, 4, 8, 16, 32]
# [4, 16, 36, 64, 100]

# %%
squares={x:x*x for x in range(1,6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
doubles={x:2*x for x in range(1,6)}
print(doubles)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10}

# %%
#how to read multiple values from the keyboard in a single line
a,b=[int(x) for x in input("Enter two numbers:").split()]
print("Product is :",a*b)
# Out:
# Enter two numbers: 5 2
# Product is : 10

# %%
a,b,c = [float(x) for x in input("Enter 3 float numbers: ").split(',')]
print("Sum is :",a+b+c)
# Out:
# Enter 3 float numbers:  5.5,3.0,6.5
# Sum is : 15.0

# %%
mycart=[10,20,800,60,70]
for item in mycart:
    if item>400:
        print("this is not in my budget")
        continue
    print(item)
else:
    print("you have purchased everything")

# %%
    while True:
        username=input("Enter username")
        password=input("Enter password")
        if username == "admin" and password=="admin":
            print("login successfull")
            break
        else:
            print("Wrong credentials")
# Out:
# Enter username cajdvhb
# Enter password anuhlas
# Wrong credentials
# Enter username admin
# Enter password admin
# login successfull

# %%
#tower of hanoi
import time
class Tower:
    def __init__(self):
        print("Welcome to tower of hanoi game")
        print()
        print("give priblem    A=[3,2,1]     B=[]     C=[]")
        print()
        print("Expected Output A=[]     B=[]     C=[3,2,1]")
        self.A=[]
        self.B=[]
        self.C=[]

    def tower(self,item):
        self.A.append(item)
        time.sleep(3)
        print("A=",self.A)
        print("Items in Tower A\n")

    def pass1(self):
        self.temp=self.A.pop(2)
        self.C.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass one completed ============================\n")
        
    def pass2(self):
        self.temp=self.A.pop(1)
        self.B.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass two completed ============================\n")

    def pass3(self):
        self.temp=self.C.pop(0)
        self.B.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass three completed ============================\n")

    def pass4(self):
        self.temp=self.A.pop(0)
        self.C.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass four completed ============================\n")

    def pass5(self):
        self.temp=self.B.pop(1)
        self.A.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass five completed ============================\n")

    def pass6(self):
        self.temp=self.B.pop(0)
        self.C.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass six completed ============================\n")

    def pass7(self):
        self.temp=self.A.pop(0)
        self.C.append(self.temp)
        time.sleep(3)
        print("A=",self.A    ,"    ",     "B=",self.B    ,"    ","C=",self.C)
        print("Pass seven completed ============================\n")

obj = Tower()
obj.tower(3)
obj.tower(2)
obj.tower(1)
obj.pass1()
obj.pass2()
obj.pass3()
obj.pass4()
obj.pass5()
obj.pass6()
obj.pass7()
# Out:
# Welcome to tower of hanoi game
#
# give priblem    A=[3,2,1]     B=[]     C=[]
#
# Expected Output A=[]     B=[]     C=[3,2,1]
# A= [3]
# Items in Tower A
#
# A= [3, 2]
# Items in Tower A
#
# A= [3, 2, 1]
# Items in Tower A
#
# A= [3, 2]      B= []      C= [1]
# Pass one completed ============================
#
# A= [3]      B= [2]      C= [1]
# Pass two completed ============================
#
# A= [3]      B= [2, 1]      C= []
# Pass three completed ============================
#
# A= []      B= [2, 1]      C= [3]
# Pass four completed ============================
#
# A= [1]      B= [2]      C= [3]
# Pass five completed ============================
#
# A= [1]      B= []      C= [3, 2]
# Pass six completed ============================
#
# A= []      B= []      C= [3, 2, 1]
# Pass seven completed ============================
