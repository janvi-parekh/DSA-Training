# %%
#instanve variabe
class New:
    def __init__(self):
        self.a=10

obj1=New()
obj2=New()
obj3=New()
obj1.a=20
print(obj1.a)
print(obj2.a)
print(obj3.a)
# Out:
# 20
# 10
# 10

# %%
#static variable
class New:
    a=10
    def __init__(self):
        self.name="JAnvi"
obj1=New()
obj2=New()
obj3=New()
New.a=50
print(obj1.a)
print(obj2.a)
print(obj3.a)
# Out:
# 50
# 50
# 50

# %%
# For every object, a separate copy of instance variables is created.
# But in case of static variables, only one copy is created
# and it is accessible by every object of the class.

class College:

    collegename = "Modern College"   # Static variable (1 memory shared)

    def __init__(self):
        self.studentname = "Prashant"   # Instance variable (separate for each object)


# Object creation
principal = College()
teacher = College()
accountant = College()

print("principal =", principal.collegename, "....", principal.studentname)
print("teacher =", teacher.collegename, "....", teacher.studentname)
print("accountant =", accountant.collegename, "....", accountant.studentname)


# Changing static variable
College.collegename = "HBD"

# Changing instance variable of only principal object
principal.studentname = "Prashant Jha"

print("\nAfter changes:\n")

print("principal =", principal.collegename, "|", principal.studentname)
print("teacher =", teacher.collegename, "|", teacher.studentname)
print("accountant =", accountant.collegename, "|", accountant.studentname)
# Out:
# principal = Modern College .... Prashant
# teacher = Modern College .... Prashant
# accountant = Modern College .... Prashant
#
# After changes:
#
# principal = HBD | Prashant Jha
# teacher = HBD | Prashant
# accountant = HBD | Prashant

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next=None

class Linklist:
    def __init__(self):
        self.head=None
ll=Linklist()
ll.head =Node(5)
second=Node(10)
third = Node(15)
fourth=Node(20)
ll.head.next=second
second.next=third
third.next=fourth

while ll.head !=None:
    print(ll.head.data,"|",ll.head.next,"->",end=" ")
    ll.head = ll.head.next
# Out:
# 5 | <__main__.Node object at 0x00000211DDBD1B20> -> 10 | <__main__.Node object at 0x00000211DDBD82C0> -> 15 | <__main__.Node object at 0x00000211DDBD8950> -> 20 | None ->

# %%
import sys 
class Node:
    def __init__(self,data):
         self.data=data
         self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        self.tail=None
        
    def addNode(self,value):
        self.node=Node(value)
        if self.head is None:
            self.head=self.node
            self.tail=self.node
        else:
            self.tail.next=self.node
            self.tail=self.node
            
    def display(self):
        while self.head!=None:
            print(self.head.data,"|","-->",end=' ')
            self.head=self.head.next
            
    def addnodebig(self,value):
        print("Add node at beginning:")
        self.node=Node(value)
        if self.head is None:
            self.head=self.node
            self.tail=self.node
        else:
            self.node.next=self.head
            self.head=self.node
            
    def addnodeinbwt(self,value,pos):
        self.node=Node(value)
        if self.head is None:
            print("No link list available to add in between" )
            self.head=node
            self.tail==node
        elif pos == 0:
            node.next=self.head
            self.head=node
        else:
            temp = self.head
            for _ in range(pos-1):
                temp=temp.next
            self.node.next=temp.next
            temp.next =node


if __name__=="__main__":
    object=linkedlist()
    while True:
        print('1.Add node linkedlist:')
        print('2.Add node in beginning:')
        print('3.Add node in between:')
        print('4.Add node end:')
        print('5.Display linked list:')
        print('6.Exit')
        ch=int(input('enter your choice:'))
        if ch==1:
            value=int(input('enter value for node:'))
            object.addNode(value)
            print('Node added successfully in single linkedlist')
        elif ch==2:
            value=int(input('enter value for node:'))
            object.addnodebig(value)
        elif ch==3:
            value=int(input('enter value for node:'))
            pos= int(input("enter the index position"))
            object.addnodeinbwt(value,pos)

        elif ch==5:
            object.display()
        elif ch==6:
            #sys.exit()
            break
# Out:
# 1.Add node linkedlist:
# 2.Add node in beginning:
# 3.Add node in between:
# 4.Add node end:
# 5.Display linked list:
# 6.Exit
# enter your choice: 6
