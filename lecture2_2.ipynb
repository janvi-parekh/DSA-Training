# %%
#tuple
mytuple=("prashant","Ashish","Rahul","sandip","komal","ankur","rajesh",23,3.14,"sandip")
print(mytuple)
print(type(mytuple))
# Out:
# ('prashant', 'Ashish', 'Rahul', 'sandip', 'komal', 'ankur', 'rajesh', 23, 3.14, 'sandip')
# <class 'tuple'>

# %%
mytuple[2]="sunil"
print(mytuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mytuple[2]="sunil"
#       2 print(mytuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
init_tuple=()
print(init_tuple.__len__())
# Out:
# 0

# %%
init_tuple_a = '1','2'
inti_tuple_b='3','4'
print(init_tuple_a + inti_tuple_b)
# Out:
# ('1', '2', '3', '4')

# %%
l=[1,2,3]
init_tuple=("Python",)*(l.__len__() -l[::-1][0])
print(init_tuple)
# Out:
# ()

# %%
init_tuple=("python",)*3
print(type(init_tuple))
init_tuple=("python")*3
print(type(init_tuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
#dictionary
mydict={101:"janvi",102:"Aastha",103:"Aarya",104:"Rishika","104":"vaibhab",101:"ashish"}
print(mydict)
a=mydict[102]
print(a)

print(mydict[102])

mydict[104]="maddy"
print(mydict[104])

for x in mydict:
    print(x)

for x in mydict.values():
    print(x)
# Out:
# {101: 'ashish', 102: 'Aastha', 103: 'Aarya', 104: 'Rishika', '104': 'vaibhab'}
# Aastha
# Aastha
# maddy
# 101
# 102
# 103
# 104
# 104
# ashish
# Aastha
# Aarya
# maddy
# vaibhab

# %%
for x,y in mydict.items():
    print(x,y)
# Out:
# 101 ashish
# 102 Aastha
# 103 Aarya
# 104 maddy
# 104 vaibhab

# %%
mydict.pop(101)
print(mydict)
# Out:
# {102: 'Aastha', 103: 'Aarya', 104: 'maddy', '104': 'vaibhab'}

# %%
my_dir={}
my_dir[1]=1
my_dir['1']=2
my_dir[1.0]=4

sum=0
for k in my_dir:
    sum+=my_dir[k]
print(sum)
# Out:
# 6

# %%
box={}
jars={}
crates={}
box['biscuit']=1
box['cake']=3
jars['jam']=4
crates['box']=box
crates['jars']=jars
print(len(crates[box]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       7 crates['box']=box
#       8 crates['jars']=jars
# ----> 9 print(len(crates[box]))
#
# TypeError: unhashable type: 'dict'

# %%
dict={'c':97,'a':96,'b':98}
for _ in sorted(dict):
    print(dict[_])
# Out:
# 96
# 98
# 97

# %%
dict={'c':97,'a':96,'b':98}
max= max(dict.keys())
print(max)
# Out:
# c

# %%
dict={'c':97,'a':96,'b':98}
min= min(dict.keys())
print(min)
# Out:
# a

# %%
num = 123456
a = num%10
num=num//10
b= num%10
num=num//10
c= num%10
num=num//10
d= num%10
num=num//10
e= num%10
f=num // 10
rev = a*100000 + b*10000 + c*1000+d*100+e*10+f*1
print (rev)
# Out:
# 654321

# %%
Amount=int(input("Please enter Amount for withdraw: "))
print("100 notes =",Amount//100)
print("50 notes =",(Amount%100)//50)
print("20 notes =",((Amount%100)%50)//20)
print("10 notes =",(((Amount%100)%50)%20)//10)
print("5 notes =",((((Amount%100)%50)%20)%10)//5)
print("2 notes =",(((((Amount%100)%50)%20)%10)%5)//2)
print("1 notes =",((((((Amount%100)%50)%20)%10)%5)%2)//1)
# Out:
# Please enter Amount for withdraw:  8561
# 100 notes = 85
# 50 notes = 1
# 20 notes = 0
# 10 notes = 1
# 5 notes = 0
# 2 notes = 0
# 1 notes = 1
